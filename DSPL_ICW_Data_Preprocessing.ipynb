# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashika0509/DSPL_ICW/blob/main/DSPL_ICW_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import random
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#read the csv
df = pd.read_csv('/content/drive/MyDrive/W2120559_DSPL_CWK2/Data/Raw Data/energy-and-mining_lka.csv')
df.head()
# Out:
#   Country Name Country ISO3  Year  \
# 0    Sri Lanka          LKA  2021
# 1    Sri Lanka          LKA  2020
# 2    Sri Lanka          LKA  2019
# 3    Sri Lanka          LKA  2018
# 4    Sri Lanka          LKA  2017
#
#                                       Indicator Name     Indicator Code  Value
# 0  Energy intensity level of primary energy (MJ/$...  EG.EGY.PRIM.PP.KD   1.67
# 1  Energy intensity level of primary energy (MJ/$...  EG.EGY.PRIM.PP.KD   1.66
# 2  Energy intensity level of primary energy (MJ/$...  EG.EGY.PRIM.PP.KD   1.61
# 3  Energy intensity level of primary energy (MJ/$...  EG.EGY.PRIM.PP.KD   1.55
# 4  Energy intensity level of primary energy (MJ/$...  EG.EGY.PRIM.PP.KD   1.59

# %%
df.shape
# Out:
# (1448, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1448 entries, 0 to 1447
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    1448 non-null   object
#  1   Country ISO3    1448 non-null   object
#  2   Year            1448 non-null   int64
#  3   Indicator Name  1448 non-null   object
#  4   Indicator Code  1448 non-null   object
#  5   Value           1448 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 68.0+ KB

# %%
df.describe()
# Out:
#               Year         Value
# count  1448.000000  1.448000e+03
# mean   2000.986878  6.693590e+06
# std      14.328189  7.845645e+07
# min    1962.000000  0.000000e+00
# 25%    1992.000000  0.000000e+00
# 50%    2003.000000  2.257416e+00
# 75%    2012.000000  4.530208e+01
# max    2024.000000  2.024220e+09

# %%
#drop row as it is unnecessary
df.drop(index=0, inplace=True)

# %%
#removing columns that dont add valuable insights
df.drop(['Country Name','Country ISO3', 'Indicator Code'], axis=1, inplace=True)

# %%
#Rename columns for readability
df.rename(columns={'Indicator Name': 'Indicator'}, inplace=True)

# %%
df.head()
# Out:
#    Year                                          Indicator  Value
# 1  2020  Energy intensity level of primary energy (MJ/$...   1.66
# 2  2019  Energy intensity level of primary energy (MJ/$...   1.61
# 3  2018  Energy intensity level of primary energy (MJ/$...   1.55
# 4  2017  Energy intensity level of primary energy (MJ/$...   1.59
# 5  2016  Energy intensity level of primary energy (MJ/$...   1.76

# %%
#check for null values
df.isnull().sum()
# Out:
# Year         0
# Indicator    0
# Value        0
# dtype: int64

# %%
#checking for duplicates
duplicates = df[df.duplicated(subset=['Indicator', 'Year', 'Value'], keep=False)]
print(duplicates.sort_values(by=['Indicator', 'Year']))
# Out:
# Empty DataFrame
# Columns: [Year, Indicator, Value]
# Index: []

# %%
#data types
df.dtypes
# Out:
# Year           int64
# Indicator     object
# Value        float64
# dtype: object

# %%
#Keep data from 2000
df = df[df['Year'] >= 2000]

# %%
#clean inconsistent values in the Value column
df['Value'] = (
    df['Value']
    .astype(str)                     # ensure it's string
    .str.replace(',', '', regex=False)  # remove commas
    .str.replace('$', '', regex=False)  # remove $ if needed
    .str.strip()                     # remove whitespace
)

# Now convert to numeric
df['Value'] = pd.to_numeric(df['Value'], errors='coerce')

# %%
df.dropna(subset=['Year', 'Value'], inplace=True)

# %%
df.dtypes
# Out:
# Year           int64
# Indicator     object
# Value        float64
# dtype: object

# %%
# Define important indicators
important_indicators = [
    "Access to electricity (% of population)",
    "Access to electricity, rural (% of rural population)",
    "Access to electricity, urban (% of urban population)",
    "Renewable energy consumption (% of total final energy consumption)",
    "Renewable electricity output (% of total electricity output)",
    "Fossil fuel energy consumption (% of total)",
    "Energy intensity level of primary energy (MJ/$ GDP)",
    "GDP per unit of energy use (constant 2017 PPP $ per kg of oil equivalent)",
    "Electricity production from oil sources (% of total)",
    "Electricity production from hydroelectric sources (% of total)",
    "Electricity production from renewable sources (% of total)",
    "Electric power transmission and distribution losses (% of output)"
]

# Filter dataset
df = df[df['Indicator'].isin(important_indicators)]

# %%
#checking for unique values
df['Indicator'].unique()
# Out:
# array(['Access to electricity, rural (% of rural population)',
#        'Access to electricity, urban (% of urban population)',
#        'Access to electricity (% of population)',
#        'Electricity production from hydroelectric sources (% of total)',
#        'Electric power transmission and distribution losses (% of output)',
#        'Electricity production from oil sources (% of total)',
#        'Renewable electricity output (% of total electricity output)',
#        'Renewable energy consumption (% of total final energy consumption)',
#        'Fossil fuel energy consumption (% of total)'], dtype=object)

# %%
#checking for unique values
df['Year'].unique()
# Out:
# array([2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013,
#        2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002,
#        2001, 2000])

# %%
#reset index after dropping
df = df.reset_index(drop=True)

# %%
#final cleaned df shape and overview
print(df.shape)
print(df.head())
# Out:
# (208, 3)
#    Year                                          Indicator  Value
# 0  2023  Access to electricity, rural (% of rural popul...  100.0
# 1  2022  Access to electricity, rural (% of rural popul...  100.0
# 2  2021  Access to electricity, rural (% of rural popul...  100.0
# 3  2020  Access to electricity, rural (% of rural popul...  100.0
# 4  2019  Access to electricity, rural (% of rural popul...   99.7

# %%
#saved the cleaned df as a csv
df.to_csv('cleaned_indicators_lka.csv', index=False)
